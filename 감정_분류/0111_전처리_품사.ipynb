# %%
import pandas as pd

# %%
df = pd.read_excel('clean_str.xlsx')
df.head()
# Out:
#                 Sentence Emotion
# 0  언니 동생으로 부르는 게 맞는 일인가요      공포
# 1          그냥 내 느낌일 뿐이겠지      공포
# 2       아직 너무 초기라서 그런 거죠      공포
# 3         유치원 버스 사고 낫다던데      공포
# 4         근데 원래 이런 거 맞나요      공포

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38516 entries, 0 to 38515
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  38516 non-null  object
#  1   Emotion   38516 non-null  object
# dtypes: object(2)
# memory usage: 601.9+ KB

# %%
# NaN 값 확인하는 여러 방법
print("1. info() 메서드로 확인:")
df.info()

print("\n2. isnull() 합계로 확인:")
print(df.isnull().sum())

print("\n3. 전체 NaN 개수 확인:")
print(df.isnull().sum().sum())
# Out:
# 1. info() 메서드로 확인:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38516 entries, 0 to 38515
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  38516 non-null  object
#  1   Emotion   38516 non-null  object
# dtypes: object(2)
# memory usage: 601.9+ KB
#
# 2. isnull() 합계로 확인:
# Sentence    0
# Emotion     0
# dtype: int64
#
# 3. 전체 NaN 개수 확인:
# 0

# %%
len(df)
# Out:
# 38516

# %%
stop_words = pd.read_csv('불용어/2_stopword_fixed.txt', header=None)

def remove_stopwords(text, stop_words):
    # 불용어 제거
    for stop_word in stop_words[0].values:
        text = text.replace(stop_word, '')
    return text

# 불용어 제거 적용
df['Sentence_cleaned'] = df['Sentence'].apply(lambda x: remove_stopwords(x, stop_words))

df.head(50)
# Out:
#                                              Sentence Emotion  \
# 0                               언니 동생으로 부르는 게 맞는 일인가요      공포
# 1                                       그냥 내 느낌일 뿐이겠지      공포
# 2                                    아직 너무 초기라서 그런 거죠      공포
# 3                                      유치원 버스 사고 낫다던데      공포
# 4                                      근데 원래 이런 거 맞나요      공포
# 5                                        남자친구가 떠날까 봐요      공포
# 6                                이거 했는데 허리가 아플 수도 있나요      공포
# 7                                       내가 불안해서 꾸는 걸까      공포
# 8                                          일주일도 안 남았다      공포
# 9                       약은 최대한 안 먹으려고 하는 데 좋은 음 시 있나요      공포
# 10                          구직활동하면서 남는 시간은 뭘로 활용해야 되지      공포
# 11                                괜찮은 분 같아서 괜히 조급해지네요      공포
# 12                       제가 스타일을 바꾸면 더 어색하게만 변할 것 같아서      공포
# 13                    아내 있으면 여자 있는 술집 가면 법 적으로 문제 있나요      공포
# 14                                     한 소리들을 지 도와주세요      공포
# 15                                         도와주실 분 없나요      공포
# 16                  그냥 잡다한 거 말고 학업에 관련된 거 듣는 게 더 좋은가요      공포
# 17                                가격은 반값 이거 질이 다른 건가요      공포
# 18  마지막에 말씀드렸던 대로 글은 이제 내릴게요의 도치 않게 실시간 베스트 글에 올라가...      공포
# 19                  화장품 회사다 보니 젊은 여자들이 많은 거 같은데 걱정이네요      공포
# 20                                           몸무게 아니겠죠      공포
# 21                                      o자 다리 많이 심한가요      공포
# 22                                        안 하는 게 나을까요      공포
# 23                                        그 정도로 더러운가요      공포
# 27                                         이거 무슨 증상이죠
# 28                                  다름 아니라 제 동생 걱정입니다
# 29                                          아무래도 무리겠죠
# 30                                     애인으로써 정말 걱정됩니다
# 31                           이러다 일주일 전에 나오는 거 아닌가 몰라요
# 32                                             경고 먹을까
# 33                                  극도로 예민하고 불안한 상태에요
# 34                                         못 받으면 어떡하죠
# 35                                        안검하수도 어울릴까요
# 36                                   근데 그게 사마귀 일수 있데요
# 37                       이제 곧 내년이면 여대생입니다 요즘 고민이 있는데요
# 38                                        안 하는 게 좋은가요
# 39                                 자제할 수 있는 방법 뭐 없을까요
# 40          집에 와서 또 운동하긴 했는데 지난 노력이 물거품이 될까 봐 정말 걱정돼요
# 41                                       옳은 선택인지 모르겠음
# 42                           둘째가 태어나서 마음이 더 조급한 것 같아요
# 43                         엄마한테는 친구랑 보러 간다 하는데 안 들키겠지
# 44                     내가 구글 폰 계정에 동기화를 안 한 거 같은데 어쩌죠
# 45                                       아니면 더 빼야 하나요
# 46                                       물을 안 먹어서 그러나
# 47                                        찾아가는 게 나을까요
# 48                                  제가 너무 깊이 들어가는 건가요
# 49                                       알 수 있는 방법 없음

# %%
from konlpy.tag import Mecab
m = Mecab(dicpath="C:/mecab/mecab-ko-dic")

# %%
tagset = pd.DataFrame(list(m.tagset.items()), columns=['태그', '품사'])
# tagset.to_excel('tagset.xlsx', index=False)

# %%
text2 = df.drop('Sentence', axis=1)
text2['Sentence_cleaned'] = text2['Sentence_cleaned'].apply(lambda x: m.pos(x))
text2.head(50)
# Out:
#    Emotion                                   Sentence_cleaned
# 0       공포  [(언니, NNG), (동생, NNG), (으로, JKB), (부르, VV), (는...
# 1       공포  [(그냥, MAG), (내, NP+JKG), (느낌, NNG), (일, VCP+ET...
# 2       공포  [(아직, MAG), (너무, MAG), (초기, NNG), (라서, VCP+EC)...
# 3       공포  [(유치원, NNG), (버스, NNG), (사고, NNG), (낫, VV), (다...
# 4       공포  [(근데, MAJ), (원래, MAG), (이런, MM), (거, NNB), (맞,...
# 5       공포  [(남자, NNG), (친구, NNG), (가, JKS), (떠날까, VV+EC),...
# 6       공포  [(이거, NP), (했, VV+EP), (는데, EC), (허리, NNG), (가...
# 7       공포  [(내, NP), (가, JKS), (불안, NNG), (해서, XSA+EC), (...
# 8       공포  [(일, NR), (주일, NNBC), (도, JX), (안, MAG), (남, V...
# 9       공포  [(약, NNG), (은, JX), (최대한, MAG), (안, MAG), (먹, ...
# 10      공포  [(구직, NNG), (활동, NNG), (하, XSV), (면서, EC), (남,...
# 11      공포  [(괜찮, VA), (은, ETM), (분, NNB), (같, VA), (아서, E...
# 12      공포  [(제, NP), (가, JKS), (스타일, NNG), (을, JKO), (바꾸,...
# 13      공포  [(아내, NNG), (있, VV), (으면, EC), (여자, NNG), (있, ...
# 14      공포  [(한, MM), (소리, NNG), (들, XSN), (을, JKO), (지, N...
# 15      공포  [(도와, VV+EC), (주, VX), (실, EP+ETM), (분, NNB), ...
# 16      공포  [(그냥, MAG), (잡다, XR), (한, XSA+ETM), (거, NNB), ...
# 17      공포  [(가격, NNG), (은, JX), (반값, NNG), (이거, NP), (질, ...
# 18      공포  [(마지막, NNG), (에, JKB), (말씀, NNG), (드렸, VV+EP),...
# 19      공포  [(화장품, NNG), (회사, NNG), (다, VCP+EC), (보, VX), ...
# 20      공포          [(몸무게, NNG), (아니, VCN), (겠, EP), (죠, EF)]
# 21      공포  [(o, SL), (자, XSN), (다리, NNG), (많이, MAG), (심한,...
# 22      공포  [(안, MAG), (하, VV), (는, ETM), (게, NNB+JKS), (나...
# 23      공포  [(그, MM), (정도, NNG), (로, JKB), (더러운, VA+ETM), ...
# 24      공포  [(보통, NNG), (가진, VV+ETM), (콩, NNG), (도, JX), (...
# 25      공포  [(여자, NNG), (가, JKS), (술, NNG), (취해서, VV+EC), ...
# 26      공포                [(걱정, NNG), (이, JKS), (큽니다, VA+EC)]
# 27      공포  [(이거, NP), (무슨, MM), (증상, NNG), (이, VCP), (죠, ...
# 28      공포  [(다름, VA+ETN), (아니, VCN), (라, EC), (제, NP+JKG)...
# 29      공포     [(아무래도, MAG), (무리, NNG), (겠, VCP+EP), (죠, EF)]
# 30      공포  [(애인, NNG), (으로써, JKB), (정말, MAG), (걱정, NNG), ...
# 31      공포  [(이러다, MAJ), (일, NR), (주일, NNBC), (전, NNG), (에...
# 32      공포                     [(경고, NNG), (먹, VV), (을까, EC)]
# 33      공포  [(극도, NNG), (로, JKB), (예민, XR), (하, XSA), (고, ...
# 34      공포  [(못, MAG), (받, VV), (으면, EC), (어떡, XR), (하, XS...
# 35      공포  [(안검, NNG), (하수, NNG), (도, JX), (어울릴까, VV+EC),...
# 36      공포  [(근데, MAJ), (그게, NP+JKS), (사마귀, NNG), (일수, NNG...
# 37      공포  [(이제, MAG), (곧, MAG), (내년, NNG), (이, VCP), (면,...
# 38      공포  [(안, MAG), (하, VV), (는, ETM), (게, NNB+JKS), (좋...
# 39      공포  [(자제, NNG), (할, XSV+ETM), (수, NNB), (있, VV), (...
# 40      공포  [(집, NNG), (에, JKB), (와서, VV+EC), (또, MAG), (운...
# 41      공포  [(옳, VA), (은, ETM), (선택, NNG), (인지, VCP+EC), (...
# 42      공포  [(둘째, NR), (가, JKS), (태어나, VV), (서, EC), (마음, ...
# 43      공포  [(엄마, NNG), (한테, JKB), (는, JX), (친구, NNG), (랑,...
# 44      공포  [(내, NP), (가, JKS), (구글, NNG), (폰, NNG), (계정, ...
# 45      공포  [(아니면, MAJ), (더, MAG), (빼, VV), (야, EF), (하나, ...
# 46      공포  [(물, NNG), (을, JKO), (안, MAG), (먹, VV), (어서, E...
# 47      공포  [(찾아가, VV), (는, ETM), (게, NNB+JKS), (나, VA), (...
# 48      공포  [(제, NP), (가, JKS), (너무, MAG), (깊이, MAG), (들어가...
# 49      공포  [(알, VV+ETM), (수, NNB), (있, VV), (는, ETM), (방법...

# %%
tags = ['NNG', 'NNP', 'VA', 'VV', 'XR']
# 'NNG': 일반 명사
# 'NNP': 고유 명사
# 'VA': 형용사
# 'VV': 동사
# 'XR': 어근

# %%
stop_word = pd.read_csv('불용어/1_stopword_fixed.txt', header=None)
text2['Sentence_cleaned'] = text2['Sentence_cleaned'].apply(lambda x: [i for i in x if i not in stop_word[0].values])
text2
# Out:
#       Emotion                                   Sentence_cleaned
# 0          공포                                    [언니, 동생, 부르, 맞]
# 1          공포                                               [느낌]
# 2          공포                                               [초기]
# 3          공포                                   [유치원, 버스, 사고, 낫]
# 4          공포                                                [맞]
# ...       ...                                                ...
# 38511      혐오                                   [예보, 세금, 아끼, 폐지]
# 38512      혐오                                           [재미, 망하]
# 38513      혐오  [공장, 도시락, 위생, 아르바이트, 화장실, 손, 씻, 재료, 담, 바닥, 떨어진...
# 38514      혐오                   [코딱지, 한, 나라, 피, 터지, 싸우, 센지, 클래스]
# 38515      혐오                      [와이프, 그렇, 댓글, 볼, 이휘재, 하차, 전해]
#
# [38516 rows x 2 columns]

# %%
text2 = text2[text2['Sentence_cleaned'].apply(lambda x: len(x) != 0)]
text2
# Out:
#       Emotion                                   Sentence_cleaned
# 0          공포                                    [언니, 동생, 부르, 맞]
# 1          공포                                               [느낌]
# 2          공포                                               [초기]
# 3          공포                                   [유치원, 버스, 사고, 낫]
# 4          공포                                                [맞]
# ...       ...                                                ...
# 38511      혐오                                   [예보, 세금, 아끼, 폐지]
# 38512      혐오                                           [재미, 망하]
# 38513      혐오  [공장, 도시락, 위생, 아르바이트, 화장실, 손, 씻, 재료, 담, 바닥, 떨어진...
# 38514      혐오                   [코딱지, 한, 나라, 피, 터지, 싸우, 센지, 클래스]
# 38515      혐오                      [와이프, 그렇, 댓글, 볼, 이휘재, 하차, 전해]
#
# [38060 rows x 2 columns]

# %%
text2.to_excel('전처리_품사_불용어.xlsx', index=False)

# %%
text2.describe
# Out:
# <bound method NDFrame.describe of       Emotion                                   Sentence_cleaned
# 0          공포                                    [언니, 동생, 부르, 맞]
# 1          공포                                               [느낌]
# 2          공포                                               [초기]
# 3          공포                                   [유치원, 버스, 사고, 낫]
# 4          공포                                                [맞]
# ...       ...                                                ...
# 38511      혐오                                   [예보, 세금, 아끼, 폐지]
# 38512      혐오                                           [재미, 망하]
# 38513      혐오  [공장, 도시락, 위생, 아르바이트, 화장실, 손, 씻, 재료, 담, 바닥, 떨어진...
# 38514      혐오                   [코딱지, 한, 나라, 피, 터지, 싸우, 센지, 클래스]
# 38515      혐오                      [와이프, 그렇, 댓글, 볼, 이휘재, 하차, 전해]
#
# [38060 rows x 2 columns]>

# %%
text2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38060 entries, 0 to 38515
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Emotion           38060 non-null  object
#  1   Sentence_cleaned  38060 non-null  object
# dtypes: object(2)
# memory usage: 892.0+ KB
